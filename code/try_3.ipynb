# %%
import ramanspy as rp

# Load training and testing datasets
X_train, y_train = rp.datasets.bacteria("train", folder="../data/bacteria/")
X_test, y_test = rp.datasets.bacteria("test", folder="../data/bacteria/")

# Load the names of the species and antibiotics corresponding to the 30 classes
y_labels, antibiotics_labels = rp.datasets.bacteria("labels")

# %%
# !pip3 install torch torchvision torchaudio
# !pip install tensorflow
# Out:
# Requirement already satisfied: torch in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: torchvision in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (0.20.1)
# Requirement already satisfied: torchaudio in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: filelock in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tensorflow in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/mitsuko/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import numpy as np
import ramanspy as rp
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load training and testing datasets
X_train, y_train = rp.datasets.bacteria("train", folder="../data/bacteria/")
X_test, y_test = rp.datasets.bacteria("test", folder="../data/bacteria/")

# Load the names of the species and antibiotics corresponding to the 30 classes
y_labels, antibiotics_labels = rp.datasets.bacteria("labels")

# Extract spectral data from SpectralContainer objects
X_train = X_train.spectral_data
X_test = X_test.spectral_data

# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Randomize the training data
indices = np.arange(X_train.shape[0])
np.random.shuffle(indices)
X_train = X_train[indices]
y_train = y_train[indices]

# Encode the labels to integers
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Convert labels to one-hot encoding
num_classes = 30
y_train_one_hot = to_categorical(y_train_encoded, num_classes)
y_test_one_hot = to_categorical(y_test_encoded, num_classes)

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_encoded), y=y_train_encoded)
class_weights = dict(enumerate(class_weights))

# Define the neural network model with regularization and batch normalization
model = models.Sequential([
    layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.6),
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.6),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.BatchNormalization(),
    layers.Dropout(0.6),
    layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping and learning rate scheduling
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# Train the model
history = model.fit(X_train, y_train_one_hot, epochs=100, batch_size=32,
                    validation_split=0.2, class_weight=class_weights,
                    callbacks=[early_stopping, reduce_lr])

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_one_hot)
print(f"Test accuracy: {test_acc:.4f}")

# Save the model
model.save("bacteria_classifier_model.h5")
# Out:
# Epoch 1/100
# /Users/mitsuko/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2331 - loss: 6.8644 - val_accuracy: 0.7595 - val_loss: 1.7226 - learning_rate: 0.0010
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5762 - loss: 2.1294 - val_accuracy: 0.8061 - val_loss: 1.4910 - learning_rate: 0.0010
# Epoch 3/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6376 - loss: 1.9873 - val_accuracy: 0.8302 - val_loss: 1.4587 - learning_rate: 0.0010
# Epoch 4/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6474 - loss: 1.9415 - val_accuracy: 0.8363 - val_loss: 1.4197 - learning_rate: 0.0010
# Epoch 5/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6607 - loss: 1.9167 - val_accuracy: 0.8291 - val_loss: 1.4011 - learning_rate: 0.0010
# Epoch 6/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6652 - loss: 1.8812 - val_accuracy: 0.8537 - val_loss: 1.3418 - learning_rate: 0.0010
# Epoch 7/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6794 - loss: 1.8419 - val_accuracy: 0.8392 - val_loss: 1.3380 - learning_rate: 0.0010
# Epoch 8/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6781 - loss: 1.8152 - val_accuracy: 0.8611 - val_loss: 1.3411 - learning_rate: 0.0010
# Epoch 9/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6815 - loss: 1.8082 - val_accuracy: 0.8422 - val_loss: 1.3198 - learning_rate: 0.0010
# Epoch 10/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6770 - loss: 1.8201 - val_accuracy: 0.8422 - val_loss: 1.3352 - learning_rate: 0.0010
# Epoch 11/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6868 - loss: 1.7780 - val_accuracy: 0.8573 - val_loss: 1.3096 - learning_rate: 0.0010
# Epoch 12/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6857 - loss: 1.7842 - val_accuracy: 0.8524 - val_loss: 1.2978 - learning_rate: 0.0010
# Epoch 13/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6854 - loss: 1.7720 - val_accuracy: 0.8692 - val_loss: 1.2844 - learning_rate: 0.0010
# Epoch 14/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6836 - loss: 1.7794 - val_accuracy: 0.8627 - val_loss: 1.2770 - learning_rate: 0.0010
# Epoch 15/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6916 - loss: 1.7372 - val_accuracy: 0.8450 - val_loss: 1.2974 - learning_rate: 0.0010
# Epoch 16/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6880 - loss: 1.7497 - val_accuracy: 0.8630 - val_loss: 1.2967 - learning_rate: 0.0010
# Epoch 17/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6974 - loss: 1.7228 - val_accuracy: 0.8563 - val_loss: 1.2673 - learning_rate: 0.0010
# Epoch 18/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6925 - loss: 1.7416 - val_accuracy: 0.8582 - val_loss: 1.2725 - learning_rate: 0.0010
# Epoch 19/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6941 - loss: 1.7280 - val_accuracy: 0.8520 - val_loss: 1.3220 - learning_rate: 0.0010
# Epoch 20/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6900 - loss: 1.7401 - val_accuracy: 0.8573 - val_loss: 1.2814 - learning_rate: 0.0010
# Epoch 21/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6920 - loss: 1.7262 - val_accuracy: 0.8577 - val_loss: 1.2886 - learning_rate: 0.0010
# Epoch 22/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6859 - loss: 1.7454 - val_accuracy: 0.8291 - val_loss: 1.2935 - learning_rate: 0.0010
# Epoch 23/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7482 - loss: 1.4159 - val_accuracy: 0.8956 - val_loss: 0.7901 - learning_rate: 2.0000e-04
# Epoch 24/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7859 - loss: 1.0588 - val_accuracy: 0.8943 - val_loss: 0.6794 - learning_rate: 2.0000e-04
# Epoch 25/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7918 - loss: 0.9516 - val_accuracy: 0.8934 - val_loss: 0.6271 - learning_rate: 2.0000e-04
# Epoch 26/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7983 - loss: 0.9075 - val_accuracy: 0.8991 - val_loss: 0.6014 - learning_rate: 2.0000e-04
# Epoch 27/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8041 - loss: 0.8719 - val_accuracy: 0.8992 - val_loss: 0.5917 - learning_rate: 2.0000e-04
# Epoch 28/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8057 - loss: 0.8728 - val_accuracy: 0.8991 - val_loss: 0.5888 - learning_rate: 2.0000e-04
# Epoch 29/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8046 - loss: 0.8616 - val_accuracy: 0.8992 - val_loss: 0.5844 - learning_rate: 2.0000e-04
# Epoch 30/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8064 - loss: 0.8613 - val_accuracy: 0.9044 - val_loss: 0.5770 - learning_rate: 2.0000e-04
# Epoch 31/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8088 - loss: 0.8615 - val_accuracy: 0.9042 - val_loss: 0.5797 - learning_rate: 2.0000e-04
# Epoch 32/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8162 - loss: 0.8400 - val_accuracy: 0.8997 - val_loss: 0.5811 - learning_rate: 2.0000e-04
# Epoch 33/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8100 - loss: 0.8653 - val_accuracy: 0.9078 - val_loss: 0.5652 - learning_rate: 2.0000e-04
# Epoch 34/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8148 - loss: 0.8495 - val_accuracy: 0.9041 - val_loss: 0.5778 - learning_rate: 2.0000e-04
# Epoch 35/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8158 - loss: 0.8456 - val_accuracy: 0.9065 - val_loss: 0.5750 - learning_rate: 2.0000e-04
# Epoch 36/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8146 - loss: 0.8580 - val_accuracy: 0.9059 - val_loss: 0.5727 - learning_rate: 2.0000e-04
# Epoch 37/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8157 - loss: 0.8475 - val_accuracy: 0.9077 - val_loss: 0.5737 - learning_rate: 2.0000e-04
# Epoch 38/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8190 - loss: 0.8416 - val_accuracy: 0.9101 - val_loss: 0.5697 - learning_rate: 2.0000e-04
# Epoch 39/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8379 - loss: 0.7765 - val_accuracy: 0.9202 - val_loss: 0.5141 - learning_rate: 4.0000e-05
# Epoch 40/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8528 - loss: 0.7010 - val_accuracy: 0.9211 - val_loss: 0.4844 - learning_rate: 4.0000e-05
# Epoch 41/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8571 - loss: 0.6721 - val_accuracy: 0.9232 - val_loss: 0.4624 - learning_rate: 4.0000e-05
# Epoch 42/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8648 - loss: 0.6374 - val_accuracy: 0.9239 - val_loss: 0.4419 - learning_rate: 4.0000e-05
# Epoch 43/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8635 - loss: 0.6202 - val_accuracy: 0.9234 - val_loss: 0.4264 - learning_rate: 4.0000e-05
# Epoch 44/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8649 - loss: 0.6092 - val_accuracy: 0.9269 - val_loss: 0.4115 - learning_rate: 4.0000e-05
# Epoch 45/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8707 - loss: 0.5893 - val_accuracy: 0.9255 - val_loss: 0.4027 - learning_rate: 4.0000e-05
# Epoch 46/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8720 - loss: 0.5676 - val_accuracy: 0.9272 - val_loss: 0.3915 - learning_rate: 4.0000e-05
# Epoch 47/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8740 - loss: 0.5539 - val_accuracy: 0.9262 - val_loss: 0.3807 - learning_rate: 4.0000e-05
# Epoch 48/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8776 - loss: 0.5404 - val_accuracy: 0.9305 - val_loss: 0.3734 - learning_rate: 4.0000e-05
# Epoch 49/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8800 - loss: 0.5280 - val_accuracy: 0.9286 - val_loss: 0.3675 - learning_rate: 4.0000e-05
# Epoch 50/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8782 - loss: 0.5295 - val_accuracy: 0.9292 - val_loss: 0.3602 - learning_rate: 4.0000e-05
# Epoch 51/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8816 - loss: 0.5185 - val_accuracy: 0.9327 - val_loss: 0.3532 - learning_rate: 4.0000e-05
# Epoch 52/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8828 - loss: 0.5050 - val_accuracy: 0.9312 - val_loss: 0.3494 - learning_rate: 4.0000e-05
# Epoch 53/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8811 - loss: 0.5033 - val_accuracy: 0.9323 - val_loss: 0.3463 - learning_rate: 4.0000e-05
# Epoch 54/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8856 - loss: 0.4925 - val_accuracy: 0.9310 - val_loss: 0.3426 - learning_rate: 4.0000e-05
# Epoch 55/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8865 - loss: 0.4940 - val_accuracy: 0.9324 - val_loss: 0.3368 - learning_rate: 4.0000e-05
# Epoch 56/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8857 - loss: 0.4856 - val_accuracy: 0.9332 - val_loss: 0.3374 - learning_rate: 4.0000e-05
# Epoch 57/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8861 - loss: 0.4840 - val_accuracy: 0.9326 - val_loss: 0.3364 - learning_rate: 4.0000e-05
# Epoch 58/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8872 - loss: 0.4744 - val_accuracy: 0.9320 - val_loss: 0.3325 - learning_rate: 4.0000e-05
# Epoch 59/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8898 - loss: 0.4693 - val_accuracy: 0.9321 - val_loss: 0.3295 - learning_rate: 4.0000e-05
# Epoch 60/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8889 - loss: 0.4682 - val_accuracy: 0.9323 - val_loss: 0.3263 - learning_rate: 4.0000e-05
# Epoch 61/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8898 - loss: 0.4606 - val_accuracy: 0.9293 - val_loss: 0.3269 - learning_rate: 4.0000e-05
# Epoch 62/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8900 - loss: 0.4658 - val_accuracy: 0.9327 - val_loss: 0.3226 - learning_rate: 4.0000e-05
# Epoch 63/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8939 - loss: 0.4516 - val_accuracy: 0.9308 - val_loss: 0.3225 - learning_rate: 4.0000e-05
# Epoch 64/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8974 - loss: 0.4429 - val_accuracy: 0.9313 - val_loss: 0.3213 - learning_rate: 4.0000e-05
# Epoch 65/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8927 - loss: 0.4534 - val_accuracy: 0.9321 - val_loss: 0.3207 - learning_rate: 4.0000e-05
# Epoch 66/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8929 - loss: 0.4574 - val_accuracy: 0.9339 - val_loss: 0.3191 - learning_rate: 4.0000e-05
# Epoch 67/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8974 - loss: 0.4403 - val_accuracy: 0.9308 - val_loss: 0.3201 - learning_rate: 4.0000e-05
# Epoch 68/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8943 - loss: 0.4455 - val_accuracy: 0.9326 - val_loss: 0.3184 - learning_rate: 4.0000e-05
# Epoch 69/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8959 - loss: 0.4403 - val_accuracy: 0.9317 - val_loss: 0.3153 - learning_rate: 4.0000e-05
# Epoch 70/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8934 - loss: 0.4430 - val_accuracy: 0.9321 - val_loss: 0.3175 - learning_rate: 4.0000e-05
# Epoch 71/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8965 - loss: 0.4431 - val_accuracy: 0.9305 - val_loss: 0.3189 - learning_rate: 4.0000e-05
# Epoch 72/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8955 - loss: 0.4424 - val_accuracy: 0.9326 - val_loss: 0.3127 - learning_rate: 4.0000e-05
# Epoch 73/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8986 - loss: 0.4395 - val_accuracy: 0.9314 - val_loss: 0.3146 - learning_rate: 4.0000e-05
# Epoch 74/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8941 - loss: 0.4403 - val_accuracy: 0.9327 - val_loss: 0.3115 - learning_rate: 4.0000e-05
# Epoch 75/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8940 - loss: 0.4374 - val_accuracy: 0.9324 - val_loss: 0.3116 - learning_rate: 4.0000e-05
# Epoch 76/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8988 - loss: 0.4371 - val_accuracy: 0.9343 - val_loss: 0.3087 - learning_rate: 4.0000e-05
# Epoch 77/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8944 - loss: 0.4429 - val_accuracy: 0.9342 - val_loss: 0.3114 - learning_rate: 4.0000e-05
# Epoch 78/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8946 - loss: 0.4334 - val_accuracy: 0.9327 - val_loss: 0.3135 - learning_rate: 4.0000e-05
# Epoch 79/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9010 - loss: 0.4219 - val_accuracy: 0.9327 - val_loss: 0.3131 - learning_rate: 4.0000e-05
# Epoch 80/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8980 - loss: 0.4322 - val_accuracy: 0.9333 - val_loss: 0.3137 - learning_rate: 4.0000e-05
# Epoch 81/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8979 - loss: 0.4304 - val_accuracy: 0.9335 - val_loss: 0.3130 - learning_rate: 4.0000e-05
# Epoch 82/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9061 - loss: 0.4092 - val_accuracy: 0.9362 - val_loss: 0.3040 - learning_rate: 8.0000e-06
# Epoch 83/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9104 - loss: 0.3962 - val_accuracy: 0.9357 - val_loss: 0.3020 - learning_rate: 8.0000e-06
# Epoch 84/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9146 - loss: 0.3917 - val_accuracy: 0.9363 - val_loss: 0.3005 - learning_rate: 8.0000e-06
# Epoch 85/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9172 - loss: 0.3741 - val_accuracy: 0.9373 - val_loss: 0.2992 - learning_rate: 8.0000e-06
# Epoch 86/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9181 - loss: 0.3738 - val_accuracy: 0.9361 - val_loss: 0.2965 - learning_rate: 8.0000e-06
# Epoch 87/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9177 - loss: 0.3738 - val_accuracy: 0.9361 - val_loss: 0.2958 - learning_rate: 8.0000e-06
# Epoch 88/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9205 - loss: 0.3638 - val_accuracy: 0.9352 - val_loss: 0.2939 - learning_rate: 8.0000e-06
# Epoch 89/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9194 - loss: 0.3643 - val_accuracy: 0.9359 - val_loss: 0.2934 - learning_rate: 8.0000e-06
# Epoch 90/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9183 - loss: 0.3625 - val_accuracy: 0.9370 - val_loss: 0.2916 - learning_rate: 8.0000e-06
# Epoch 91/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9209 - loss: 0.3610 - val_accuracy: 0.9370 - val_loss: 0.2902 - learning_rate: 8.0000e-06
# Epoch 92/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9214 - loss: 0.3564 - val_accuracy: 0.9375 - val_loss: 0.2902 - learning_rate: 8.0000e-06
# Epoch 93/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9204 - loss: 0.3558 - val_accuracy: 0.9373 - val_loss: 0.2898 - learning_rate: 8.0000e-06
# Epoch 94/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9237 - loss: 0.3470 - val_accuracy: 0.9369 - val_loss: 0.2880 - learning_rate: 8.0000e-06
# Epoch 95/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9222 - loss: 0.3483 - val_accuracy: 0.9381 - val_loss: 0.2871 - learning_rate: 8.0000e-06
# Epoch 96/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9207 - loss: 0.3528 - val_accuracy: 0.9377 - val_loss: 0.2860 - learning_rate: 8.0000e-06
# Epoch 97/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9253 - loss: 0.3419 - val_accuracy: 0.9376 - val_loss: 0.2856 - learning_rate: 8.0000e-06
# Epoch 98/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9250 - loss: 0.3426 - val_accuracy: 0.9373 - val_loss: 0.2856 - learning_rate: 8.0000e-06
# Epoch 99/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9266 - loss: 0.3406 - val_accuracy: 0.9371 - val_loss: 0.2847 - learning_rate: 8.0000e-06
# Epoch 100/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9279 - loss: 0.3316 - val_accuracy: 0.9364 - val_loss: 0.2844 - learning_rate: 8.0000e-06
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.4278 - loss: 4.8174
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.4077
